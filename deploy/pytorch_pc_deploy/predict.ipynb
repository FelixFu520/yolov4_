# %%
#-------------------------------------#
#       对单张图片进行预测
#-------------------------------------#
from yolo import YOLO
from PIL import Image

yolo = YOLO()

image = Image.open("street.jpg")
# image = Image.open("test.png")
r_image = yolo.detect_image(image)
# Out:
# Loading weights into state dict...
# Finished!
# ../../model_data/yolo4_weights.pth model, anchors, and classes loaded.
# CPU infer time: 35.40825653076172
# GPU infer time: 2.274637222290039
# (tensor([[[[ 1.7111e+00,  1.0599e-01,  1.2194e-01,  ...,  1.6681e-01,
#             8.1053e-01, -2.1574e+00],
#           [ 1.4341e+00,  1.6653e-01, -4.4470e-02,  ...,  4.9156e-01,
#             4.6547e-01, -1.2572e+00],
#           [ 1.5172e+00,  7.1103e-01, -4.3231e-01,  ..., -1.8112e-01,
#            -1.7359e-01, -1.3961e+00],
#           ...,
#           [ 9.6991e-01, -5.5161e-01, -7.6257e-01,  ...,  6.2961e-01,
#             1.2938e-01, -8.6855e-01],
#           [ 9.5401e-01, -5.6553e-01, -1.8620e-01,  ...,  4.1637e-01,
#             5.1841e-01, -9.5237e-01],
#           [ 1.8059e+00, -1.3724e-01, -2.6360e-02,  ..., -1.1109e-01,
#             2.3332e-02, -2.1130e+00]],
#
#          [[ 1.7788e+00,  1.2680e+00,  8.4370e-01,  ...,  1.4379e+00,
#             1.5585e+00,  1.8150e+00],
# ...

# %% [markdown]
# ```
# tensor([[[[ 1.5899e+00,  3.6284e-01,  1.5781e-01,  ...,  1.9798e-01,
#            -5.1218e-01, -1.5639e+00],
#           [ 1.1989e+00,  4.5848e-01, -2.4580e-01,  ...,  1.0899e-01,
#            -1.4476e-01, -1.2154e+00],
#           [ 1.0147e+00,  2.5516e-01,  1.7951e-02,  ...,  1.3724e-03,
#            -1.2332e-01, -1.0786e+00],
#           ...,
#           [ 6.4132e-01, -1.0425e+00, -4.7261e-02,  ..., -4.5974e-01,
#             8.0840e-02, -1.1245e+00],
#           [ 7.2942e-01, -1.2938e+00, -6.0417e-01,  ..., -5.2908e-01,
#             2.2503e-01, -1.4040e+00],
#           [ 1.6184e+00,  8.7646e-01,  3.7244e-01,  ..., -1.0817e+00,
#            -5.7190e-01, -1.3849e+00]],
#
#          [[ 1.3894e+00,  1.2585e+00,  1.1115e+00,  ...,  5.8240e-01,
#             1.0725e+00,  1.7949e+00],
#           [ 4.7186e-01,  3.6564e-01,  4.9435e-01,  ..., -1.0112e-02,
#             2.1701e-02,  4.3144e-01],
#           [ 2.9262e-01,  2.6350e-01,  6.9621e-01,  ...,  2.3130e-01,
#             5.5892e-02,  1.3338e-01],
#           ...,
#           [ 4.0806e-01, -4.2217e-01,  6.7647e-01,  ...,  2.7798e-02,
#             1.5699e-02, -3.8636e-01],
#           [-2.9211e-01, -3.9874e-01, -8.1619e-01,  ..., -1.9258e-01,
#            -4.1070e-01,  1.7898e-01],
#           [-1.6045e+00, -1.3575e+00, -6.0993e-02,  ..., -6.7541e-01,
#            -1.3330e+00, -1.4164e+00]],
#
#          [[-2.8637e-01,  1.1535e-01,  2.5631e-01,  ...,  1.0777e-01,
#            -1.0553e-01, -3.2478e-01],
#           [-7.8630e-01, -3.4406e-01, -2.2884e-01,  ...,  9.2000e-02,
#            -3.1623e-01, -8.2070e-01],
#           [-9.7897e-01, -3.6523e-01,  1.3738e-02,  ...,  4.9834e-02,
#            -3.8192e-01, -9.6495e-01],
#           ...,
#           [-1.2950e+00, -7.3377e-01, -3.9872e-01,  ...,  1.8929e-01,
#            -3.1457e-01, -9.4299e-01],
#           [-1.4028e+00, -7.8960e-01, -3.4309e-03,  ...,  1.7244e-01,
#            -3.9174e-01, -7.1782e-01],
#           [-5.7479e-01, -1.5904e-01,  7.3089e-02,  ...,  3.2080e-01,
#             1.8374e-01, -1.0344e-01]],
#
#          ...,
#
#          [[-4.7254e+00, -4.4316e+00, -4.3406e+00,  ..., -4.3268e+00,
#            -4.1757e+00, -5.0590e+00],
#           [-3.7456e+00, -4.2319e+00, -4.1400e+00,  ..., -4.8881e+00,
#            -4.5741e+00, -4.5495e+00],
#           [-3.7714e+00, -4.1037e+00, -4.6675e+00,  ..., -4.9496e+00,
#            -4.5522e+00, -4.5624e+00],
#           ...,
#           [-7.7858e+00, -8.3142e+00, -8.3143e+00,  ..., -7.7123e+00,
#            -7.6173e+00, -6.0273e+00],
#           [-9.3906e+00, -9.6683e+00, -1.0267e+01,  ..., -7.4785e+00,
#            -7.6109e+00, -6.1150e+00],
#           [-9.5742e+00, -9.4285e+00, -1.0929e+01,  ..., -8.8470e+00,
#            -8.4123e+00, -7.1569e+00]],
#
#          [[-5.3196e+00, -4.9563e+00, -5.0347e+00,  ..., -5.8187e+00,
#            -5.5513e+00, -5.8806e+00],
#           [-4.8866e+00, -4.8503e+00, -4.9240e+00,  ..., -5.7465e+00,
#            -5.4184e+00, -5.8414e+00],
#           [-5.3302e+00, -5.5758e+00, -6.5044e+00,  ..., -6.3047e+00,
#            -5.9193e+00, -6.3496e+00],
#           ...,
#           [-7.2579e+00, -8.2029e+00, -8.6757e+00,  ..., -8.6196e+00,
#            -8.3774e+00, -7.8889e+00],
#           [-8.0993e+00, -9.0379e+00, -9.4962e+00,  ..., -8.9832e+00,
#            -9.1344e+00, -9.1123e+00],
#           [-8.6257e+00, -8.5512e+00, -8.4281e+00,  ..., -9.2471e+00,
#            -9.5147e+00, -9.6370e+00]],
#
#          [[-6.6283e+00, -6.5855e+00, -6.8488e+00,  ..., -6.2139e+00,
#            -5.7611e+00, -6.1034e+00],
#           [-5.9607e+00, -6.7526e+00, -7.3572e+00,  ..., -6.3687e+00,
#            -5.6354e+00, -5.6082e+00],
#           [-6.2674e+00, -7.2372e+00, -8.4524e+00,  ..., -7.2608e+00,
#            -6.2981e+00, -6.1592e+00],
#           ...,
#           [-7.5157e+00, -7.3049e+00, -6.6915e+00,  ..., -8.0708e+00,
#            -8.2466e+00, -7.5929e+00],
#           [-8.6368e+00, -7.8510e+00, -5.7079e+00,  ..., -7.6131e+00,
#            -8.2041e+00, -8.3491e+00],
#           [-9.4773e+00, -7.0350e+00, -4.3599e+00,  ..., -7.7392e+00,
#            -8.3894e+00, -8.9545e+00]]]], device='cuda:0')
# ```
